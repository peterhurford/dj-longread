# %%
import pandas as pd
links = pd.read_csv('data/export.csv')
links
# Out:
#             id                                                url  \
# 0            0  http://moralitylab.bc.edu/wp-content/uploads/2...
# 1            1              http://www.jefftk.com/news/2013-04-01
# 2            2  http://calnewport.com/blog/2013/03/24/how-to-w...
# 3            3  http://www.freakonomics.com/2012/10/31/an-alte...
# 4            4  http://www.wired.com/vanish/2009/11/ff_vanish2...
# ...        ...                                                ...
# 117208  183171  https://thezvi.substack.com/p/monthly-roundup-...
# 117209  183172    https://www.slowboring.com/p/tuesday-thread-e30
# 117210  183173  https://www.askamanager.org/2024/12/coworkers-...
# 117211  183174  https://blog.sentinel-team.org/p/sentinel-minu...
# 117212  183175  https://www.askamanager.org/2024/12/update-my-...
#
#                                                     title  \
# 0       Moral Realism As Moral Motivation: The Impact ...
# ...

# %%
links = links[['title', 'url', 'aggregator', 'liked', 'added']]
links
# Out:
#                                                     title  \
# 0       Moral Realism As Moral Motivation: The Impact ...
# 1                    The Unintuitive Power Laws of Giving
# 2       How to Write Six Important Papers a Year witho...
# 3                             An Alternative to Democracy
# 4       Writer Evan Ratliff Tried to Vanish: Here's Wh...
# ...                                                   ...
# 117208                 Monthly Roundup #25: December 2024
# 117209                                     Tuesday thread
# 117210  "coworker’s husband punched me after the Chris...
# 117211  "Sentinel minutes for week #51/2024: OpenAI o3...
# 117212  update: my employee is passing off ChatGPT lis...
#
#                                                       url  aggregator  liked  \
# 0       http://moralitylab.bc.edu/wp-content/uploads/2...         NaN    1.0
# 1                   http://www.jefftk.com/news/2013-04-01         NaN    1.0
# ...

# %%
links[links['liked'] == 1]
# Out:
#                                                     title  \
# 0       Moral Realism As Moral Motivation: The Impact ...
# 1                    The Unintuitive Power Laws of Giving
# 2       How to Write Six Important Papers a Year witho...
# 3                             An Alternative to Democracy
# 4       Writer Evan Ratliff Tried to Vanish: Here's Wh...
# ...                                                   ...
# 115156                   The tired dance of the demagogue
# 115215  Trump Campaign Diverts Ground Game Cash Toward...
# 115218  "trainer had religious messages on his present...
# 115223  Israel’s Focus Shifts North After Electronics ...
# 116657          How Did You Do On The AI Art Turing Test?
#
#                                                       url  aggregator  liked  \
# 0       http://moralitylab.bc.edu/wp-content/uploads/2...         NaN    1.0
# 1                   http://www.jefftk.com/news/2013-04-01         NaN    1.0
# ...

# %%
links[links['liked'] == 1].reset_index(drop=True).to_csv('data/extract_liked_links.csv')
